# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk import ngrams
from collections import Counter
import re
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SEHER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#POS-Tag yapması için bir fonksiyon yazıyorum...
def tagging(sent):

    lower_case=sent.lower()
    tokens=nltk.word_tokenize(lower_case)
    tags=nltk.pos_tag(tokens)
    counts=Counter(tag for word,tag in tags)
    print (counts)

# %%
#stopwordsleri ayıklayan fonksiyon
def clean(text):
    wnl=nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')

    words = re.sub(r'[^\w\s]',"",text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
#uni-gram veren fonksiyon
def unigram(text):
    unigram=nltk.ngrams(words,1)
    unigramFrequency=Counter(unigram)
    valuesOfUnigram=list(unigramFrequency.values())
    unigramlist=list(unigramFrequency)

    for x in range (0,len(unigramlist)):
        if(valuesOfUnigram[x]>2):
            print(unigramlist[x],"is used",valuesOfUnigram[x],"times")

# %%
#2-gramları veren fonksiyon
def bigram(text):
    biagrams=nltk.ngrams(words,2)
    biagramsFrequency=Counter(biagrams)
    valuesOfBiagrams=list(biagramsFrequency.values())
    biagramlist=list(biagramsFrequency)

    for x in range (0,len(biagramlist)):
        if(valuesOfBiagrams[x]>1):
            print(biagramlist[x],"is used",valuesOfBiagrams[x],"times")

# %%
#3-gramları veren fonksiyon
def trigram(text):
    
    trigrams=nltk.ngrams(words,3)
    trigramsFrequency=Counter(trigrams)
    valuesOfTrigrams=list(trigramsFrequency.values())
    triagramlist=list(trigramsFrequency)

    for x in range (0,len(triagramlist)):
        if(valuesOfTrigrams[x]>1):
            print(triagramlist[x],"is used",valuesOfTrigrams[x],"times")

# %%
f=open(r"C:\Users\SEHER\OneDrive\Masaüstü\coffee.txt","r")
coffee =f.read()

# %%
words = clean(coffee)
words
# Out:
# ['Overview',
#  'Information',
#  'Coffee',
#  'drink',
#  'made',
#  'coffee',
#  'bean',
#  'roasted',
#  'fruit',
#  'Coffea',
#  'arabica',
#  'bush',
#  'People',
#  'commonly',
#  'drink',
#  'coffee',
#  'relieve',
#  'mental',
#  'physical',
#  'fatigue',
#  'increase',
#  'mental',
#  'alertness',
#  'Coffee',
#  'also',
#  'used',
#  'prevent',
#  'Parkinson',
#  'disease',
#  'dementia',
#  'many',
#  'condition',
#  'good',
#  'scientific',
#  'evidence',
#  'support',
#  'many',
#  'us',
#  'Rectally',
#  'coffee',
#  'used',
#  'enema',
#  'treat',
#  'cancer',
#  'Coffee',
#  'enema',
#  'used',
#  'part',
#  'Gerson',
#  'Therapy',
#  'In',
#  'Gerson',
#  'Therapy',
#  'cancer',
#  'patient',
#  'treated',
#  'caffeinated',
#  'coffee',
#  'form',
#  'enema',
#  'every',
#  'four',
#  'hour',
#  'daily',
#  'basis',
#  'During',
#  'treatment',
#  'people',
#  'given',
#  'diet',
#  'liver',
#  'vegetable',
#  'variety',
#  'supplement',
#  'This',
#  'type',
#  'therapy',
#  'considered',
#  'unacceptable',
#  'medical',
#  'practice',
#  'US',
#  'How',
#  'work',
#  'Coffee',
#  'contains',
#  'caffeine',
#  'Caffeine',
#  'work',
#  'stimulating',
#  'central',
#  'nervous',
#  'system',
#  'CNS',
#  'heart',
#  'muscle',
#  'Coffee',
#  'also',
#  'contains',
#  'chemical',
#  'might',
#  'benefit',
#  'Uses',
#  'Effectiveness',
#  'Likely',
#  'Effective',
#  'Mental',
#  'alertness',
#  'Drinking',
#  'coffee',
#  'beverage',
#  'contain',
#  'caffeine',
#  'throughout',
#  'day',
#  'seems',
#  'increase',
#  'alertness',
#  'clear',
#  'thinking',
#  'Caffeine',
#  'also',
#  'improve',
#  'alertness',
#  'sleep',
#  'deprivation',
#  'Even',
#  'one',
#  'drink',
#  'coffee',
#  'reduce',
#  'fatigue',
#  'increase',
#  'alertness',
#  'Possibly',
#  'Effective',
#  'Impaired',
#  'movement',
#  'food',
#  'intestine',
#  'surgery',
#  'Drinking',
#  'coffee',
#  'might',
#  'shorten',
#  'time',
#  'first',
#  'bowel',
#  'movement',
#  'part',
#  'colon',
#  'removed',
#  'surgery',
#  'gynecological',
#  'cancer',
#  'Diabetes',
#  'People',
#  'drink',
#  'coffee',
#  'seem',
#  'lower',
#  'risk',
#  'developing',
#  'type',
#  '2',
#  'diabetes',
#  'The',
#  'greater',
#  'intake',
#  'coffee',
#  'lower',
#  'risk',
#  'Gallbladder',
#  'disease',
#  'People',
#  'drink',
#  'beverage',
#  'coffee',
#  'provide',
#  'least',
#  '400',
#  'mg',
#  'caffeine',
#  'per',
#  'day',
#  'seem',
#  'lower',
#  'risk',
#  'developing',
#  'gallstone',
#  'The',
#  'greater',
#  'intake',
#  'caffeine',
#  'lower',
#  'risk',
#  'High',
#  'level',
#  'cholesterol',
#  'fat',
#  'lipid',
#  'blood',
#  'hyperlipidemia',
#  'Drinking',
#  'caffeinated',
#  'coffee',
#  'seems',
#  'reduce',
#  'level',
#  'total',
#  'cholesterol',
#  'LDL',
#  'bad',
#  'cholesterol',
#  'blood',
#  'fat',
#  'called',
#  'triglyceride',
#  'small',
#  'amount',
#  'Drinking',
#  'least',
#  '68',
#  'cup',
#  'caffeinated',
#  'coffee',
#  'per',
#  'day',
#  'might',
#  'greatest',
#  'benefit',
#  'Drinking',
#  'decaffeinated',
#  'coffee',
#  'appear',
#  'effect',
#  'Low',
#  'blood',
#  'pressure',
#  'Drinking',
#  'caffeinated',
#  'beverage',
#  'like',
#  'coffee',
#  'seems',
#  'increase',
#  'blood',
#  'pressure',
#  'elderly',
#  'people',
#  'experience',
#  'dizziness',
#  'meal',
#  'due',
#  'low',
#  'blood',
#  'pressure',
#  'Death',
#  'cause',
#  'People',
#  'drink',
#  'coffee',
#  'every',
#  'day',
#  'seem',
#  'lower',
#  'chance',
#  'dying',
#  'cause',
#  'heart',
#  'disease',
#  'compared',
#  'never',
#  'drink',
#  'coffee',
#  'Its',
#  'unclear',
#  'drinking',
#  'coffee',
#  'linked',
#  'lower',
#  'chance',
#  'death',
#  'due',
#  'cancer',
#  'Parkinson',
#  'disease',
#  'There',
#  'evidence',
#  'people',
#  'drink',
#  'caffeinated',
#  'beverage',
#  'coffee',
#  'tea',
#  'cola',
#  'decreased',
#  'risk',
#  'Parkinson',
#  'disease',
#  'Interestingly',
#  'coffee',
#  'seem',
#  'help',
#  'prevent',
#  'Parkinson',
#  'disease',
#  'people',
#  'smoke',
#  'cigarette',
#  'Possibly',
#  'Ineffective',
#  'Cancer',
#  'esophagus',
#  'People',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'chance',
#  'developing',
#  'cancer',
#  'esophagus',
#  'Insufficient',
#  'Evidence',
#  'Hardening',
#  'artery',
#  'atherosclerosis',
#  'The',
#  'buildup',
#  'calciumcontaining',
#  'plaque',
#  'artery',
#  'early',
#  'sign',
#  'possible',
#  'atherosclerosis',
#  'Drinking',
#  'coffee',
#  'doesnt',
#  'seem',
#  'linked',
#  'lower',
#  'buildup',
#  'calciumcontaining',
#  'plaque',
#  'artery',
#  'Irregular',
#  'heartbeat',
#  'atrial',
#  'fibrillation',
#  'People',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'risk',
#  'atrial',
#  'fibrillation',
#  'Brain',
#  'cancer',
#  'Some',
#  'early',
#  'evidence',
#  'suggests',
#  'Asian',
#  'people',
#  'drink',
#  'coffee',
#  'lower',
#  'risk',
#  'developing',
#  'brain',
#  'cancer',
#  'This',
#  'true',
#  'American',
#  'people',
#  'Bladder',
#  'cancer',
#  'Some',
#  'evidence',
#  'suggests',
#  'people',
#  'drink',
#  'coffee',
#  'lower',
#  'chance',
#  'developing',
#  'bladder',
#  'cancer',
#  'But',
#  'research',
#  'suggests',
#  'people',
#  'drink',
#  'coffee',
#  'might',
#  'higher',
#  'risk',
#  'developing',
#  'bladder',
#  'cancer',
#  'Breast',
#  'cancer',
#  'People',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'chance',
#  'developing',
#  'breast',
#  'cancer',
#  'Memory',
#  'thinking',
#  'skill',
#  'cognitive',
#  'function',
#  'There',
#  'developing',
#  'evidence',
#  'drinking',
#  'coffee',
#  'lifetime',
#  'might',
#  'improve',
#  'thinking',
#  'skill',
#  'among',
#  'woman',
#  'older',
#  '80',
#  'year',
#  'age',
#  'Coffee',
#  'also',
#  'might',
#  'improve',
#  'thinking',
#  'speed',
#  'certain',
#  'type',
#  'memory',
#  'healthy',
#  'adult',
#  'Colon',
#  'cancer',
#  'rectal',
#  'cancer',
#  'There',
#  'evidence',
#  'Japanese',
#  'people',
#  'drink',
#  'coffee',
#  'lower',
#  'chance',
#  'developing',
#  'colon',
#  'rectal',
#  'cancer',
#  'But',
#  'research',
#  'conducted',
#  'North',
#  'America',
#  'Europe',
#  'found',
#  'link',
#  'drinking',
#  'coffee',
#  'risk',
#  'colon',
#  'rectal',
#  'cancer',
#  'Diseases',
#  'Alzheimer',
#  'disease',
#  'interfere',
#  'thinking',
#  'dementia',
#  'People',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'chance',
#  'dementia',
#  'Depression',
#  'People',
#  'drink',
#  'coffee',
#  'might',
#  'lower',
#  'chance',
#  'depression',
#  'Cancer',
#  'lining',
#  'uterus',
#  'endometrial',
#  'cancer',
#  'The',
#  'effect',
#  'coffee',
#  'risk',
#  'endometrial',
#  'cancer',
#  'unclear',
#  'Some',
#  'research',
#  'suggests',
#  'woman',
#  'drink',
#  'coffee',
#  'lower',
#  'risk',
#  'developing',
#  'endometrial',
#  'cancer',
#  'But',
#  'research',
#  'found',
#  'link',
#  'drinking',
#  'coffee',
#  'risk',
#  'endometrial',
#  'cancer',
#  'Stomach',
#  'cancer',
#  'People',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'risk',
#  'stomach',
#  'cancer',
#  'Gout',
#  'There',
#  'evidence',
#  'caffeinated',
#  'decaffeinated',
#  'coffee',
#  'seem',
#  'help',
#  'prevent',
#  'gout',
#  'But',
#  'caffeinated',
#  'coffee',
#  'seems',
#  'work',
#  'better',
#  'High',
#  'blood',
#  'pressure',
#  'People',
#  'drink',
#  'coffee',
#  'longterm',
#  'might',
#  'lower',
#  'chance',
#  'developing',
#  'high',
#  'blood',
#  'pressure',
#  'But',
#  'smoking',
#  'seems',
#  'diminish',
#  'benefit',
#  'Liver',
#  'cancer',
#  'People',
#  'drink',
#  'coffee',
#  'might',
#  'lower',
#  'risk',
#  'liver',
#  'cancer',
#  'Liver',
#  'disease',
#  'People',
#  'drink',
#  'coffee',
#  'might',
#  'lower',
#  'risk',
#  'liver',
#  'disease',
#  'Lung',
#  'cancer',
#  'Some',
#  'research',
#  'suggests',
#  'drinking',
#  'caffeinated',
#  'coffee',
#  'may',
#  'help',
#  'prevent',
#  'lung',
#  'cancer',
#  'research',
#  'disagrees',
#  'Its',
#  'early',
#  'draw',
#  'firm',
#  'conclusion',
#  'Meanwhile',
#  'research',
#  'suggests',
#  'drinking',
#  'decaffeinated',
#  'coffee',
#  'may',
#  'help',
#  'prevent',
#  'lung',
#  'cancer',
#  'The',
#  'serious',
#  'type',
#  'skin',
#  'cancer',
#  'melanoma',
#  'When',
#  'factor',
#  'age',
#  'sun',
#  'exposure',
#  'taken',
#  'account',
#  'drinking',
#  'coffee',
#  'doesnt',
#  'seem',
#  'linked',
#  'lower',
#  'chance',
#  'developing',
#  'skin',
#  'cancer',
#  'Build',
#  'fat',
#  'liver',
#  'people',
#  'drink',
#  'little',
#  'alcohol',
#  'nonalcoholic',
#  'fatty',
#  'liver',
#  'disease',
#  'NAFLD',
#  'Early',
#  'research',
#  'suggests',
#  'drinking',
#  'coffee',
#  'linked',
#  'reduced',
#  'risk',
#  'NAFLD',
#  'reduced',
#  'liver',
#  'scarring',
#  'people',
#  'already',
#  'NAFLD',
#  'compared',
#  'drinking',
#  'coffee',
#  'Obesity',
#  'The',
#  'effect',
#  'coffee',
#  'weight',
#  'loss',
#  'people',
#  'overweight',
#  'obese',
#  'unclear',
#  'Results',
#  'research',
#  'conflicting',
#  'Some',
#  'research',
#  'suggests',
#  'taking',
#  'coffee',
#  'chemical',
#  'called',
#  'mannooligosaccharides',
#  '12',
#  'week',
#  'might',
#  'help',
#  'weight',
#  'loss',
#  'men',
#  'woman',
#  'Drinking',
#  'dark',
#  'roast',
#  'coffee',
#  'seems',
#  'help',
#  'reduce',
#  'food',
#  'intake',
#  'help',
#  'weight',
#  'loss',
#  'whereas',
#  'light',
#  'roast',
#  'coffee',
#  'Other',
#  'research',
#  'suggests',
#  'drinking',
#  'coffee',
#  'without',
#  'caffeine',
#  'help',
#  'weight',
#  'loss',
#  'Mouth',
#  'cancer',
#  'People',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'risk',
#  'mouth',
#  'cancer',
#  'Swelling',
#  'inflammation',
#  'pancreas',
#  'pancreatitis',
#  'Some',
#  'early',
#  'research',
#  'suggests',
#  'drinking',
#  '3',
#  'cup',
#  'coffee',
#  'reduces',
#  'pancreatitis',
#  'risk',
#  'A',
#  'type',
#  'throat',
#  'cancer',
#  'pharyngeal',
#  'cancer',
#  'People',
#  'drink',
#  'coffee',
#  'might',
#  'lower',
#  'chance',
#  'developing',
#  'pharyngeal',
#  'cancer',
#  'Prostate',
#  'cancer',
#  'In',
#  'general',
#  'people',
#  'drink',
#  'coffee',
#  'dont',
#  'seem',
#  'lower',
#  'risk',
#  'developing',
#  'prostate',
#  'cancer',
#  'But',
#  'drinking',
#  'coffee',
#  'linked',
#  'lower',
#  'risk',
#  'localized',
#  'prostate',
#  'cancer',
#  'This',
#  'prostate',
#  'cancer',
#  'spread',
#  'outside',
#  'prostate',
#  'Skin',
#  'cancer',
#  'Some',
#  'research',
#  'show',
#  'drinking',
#  'many',
#  'cup',
#  'coffee',
#  'per',
#  'day',
#  'might',
#  'reduce',
#  'risk',
#  'specific',
#  'form',
#  'skin',
#  'cancer',
#  'called',
#  'basal',
#  'cell',
#  'carcinoma',
#  'form',
#  'skin',
#  'cancer',
#  'Drinking',
#  'decaf',
#  'decaffeinated',
#  'coffee',
#  'effect',
#  'skin',
#  'cancer',
#  'risk',
#  'The',
#  'effect',
#  'skin',
#  'cancer',
#  'might',
#  'caffeine',
#  'coffee',
#  'Attention',
#  'deficithyperactivity',
#  'disorder',
#  'ADHD',
#  'Constipation',
#  'Other',
#  'condition',
#  'More',
#  'evidence',
#  'needed',
#  'rate',
#  'effectiveness',
#  'coffee',
#  'us',
#  'Side',
#  'Effects',
#  'Safety',
#  'When',
#  'taken',
#  'mouth',
#  'Coffee',
#  'LIKELY',
#  'SAFE',
#  'healthy',
#  'adult',
#  'consumed',
#  'moderate',
#  'amount',
#  '4',
#  'cup',
#  'per',
#  'day',
#  'Coffee',
#  'containing',
#  'caffeine',
#  'cause',
#  'insomnia',
#  'nervousness',
#  'restlessness',
#  'stomach',
#  'upset',
#  'nausea',
#  'vomiting',
#  'increased',
#  'heart',
#  'breathing',
#  'rate',
#  'side',
#  'effect',
#  'Drinking',
#  'unfiltered',
#  'coffee',
#  'increase',
#  'total',
#  'cholesterol',
#  'lowdensity',
#  'lipoprotein',
#  'LDL',
#  'cholesterol',
#  'level',
#  'another',
#  'type',
#  'blood',
#  'fat',
#  'called',
#  'triglyceride',
#  'This',
#  'might',
#  'increase',
#  'risk',
#  'developing',
#  'heart',
#  'disease',
#  'Using',
#  'coffee',
#  'filter',
#  'help',
#  'reduce',
#  'effect',
#  'cholesterol',
#  'Caffeinated',
#  'coffee',
#  'POSSIBLY',
#  'UNSAFE',
#  'taken',
#  'mouth',
#  'long',
#  'time',
#  'high',
#  'dos',
#  '4',
#  'cup',
#  'per',
#  'day',
#  'Drinking',
#  'large',
#  'amount',
#  'caffeinated',
#  'coffee',
#  'might',
#  'cause',
#  'headache',
#  'anxiety',
#  'agitation',
#  'ringing',
#  'ear',
#  'irregular',
#  'heartbeat',
#  'Drinking',
#  '6',
#  'cup',
#  'daily',
#  'might',
#  'cause',
#  'caffeinism',
#  'symptom',
#  'anxiety',
#  'agitation',
#  'Also',
#  'people',
#  'drink',
#  'lot',
#  'caffeinated',
#  'coffee',
#  'every',
#  'day',
#  'may',
#  'need',
#  'drink',
#  'coffee',
#  'get',
#  'effect',
#  'They',
#  'may',
#  'also',
#  'become',
#  'dependent',
#  'coffee',
#  'point',
#  'develop',
#  'withdrawal',
#  'symptom',
#  'suddenly',
#  'stop',
#  'drinking',
#  'There',
#  'concern',
#  'drinking',
#  '5',
#  'cup',
#  'coffee',
#  'per',
#  ...]

# %%
unigram1 = unigram(coffee)
# Out:
# ('Coffee',) is used 18 times
# ('drink',) is used 33 times
# ('coffee',) is used 140 times
# ('People',) is used 16 times
# ('increase',) is used 34 times
# ('alertness',) is used 5 times
# ('also',) is used 13 times
# ('used',) is used 9 times
# ('prevent',) is used 5 times
# ('Parkinson',) is used 4 times
# ('disease',) is used 16 times
# ('dementia',) is used 3 times
# ('many',) is used 6 times
# ('condition',) is used 3 times
# ('evidence',) is used 9 times
# ('enema',) is used 6 times
# ('cancer',) is used 45 times
# ('caffeinated',) is used 14 times
# ('form',) is used 3 times
# ('every',) is used 3 times
# ('hour',) is used 10 times
# ('daily',) is used 5 times
# ('people',) is used 21 times
# ('given',) is used 3 times
# ('liver',) is used 6 times
# ('supplement',) is used 3 times
# ('This',) is used 9 times
# ('type',) is used 9 times
# ('work',) is used 5 times
# ('contains',) is used 7 times
# ('caffeine',) is used 68 times
# ('Caffeine',) is used 4 times
# ('nervous',) is used 5 times
# ('system',) is used 5 times
# ('heart',) is used 17 times
# ('chemical',) is used 4 times
# ('might',) is used 49 times
# ('benefit',) is used 3 times
# ('Drinking',) is used 25 times
# ('beverage',) is used 5 times
# ('day',) is used 14 times
# ('seems',) is used 6 times
# ('thinking',) is used 5 times
# ('improve',) is used 3 times
# ('one',) is used 4 times
# ('reduce',) is used 6 times
# ('food',) is used 4 times
# ('time',) is used 5 times
# ('bowel',) is used 3 times
# ('colon',) is used 3 times
# ('Diabetes',) is used 3 times
# ('seem',) is used 18 times
# ('lower',) is used 26 times
# ('risk',) is used 35 times
# ('developing',) is used 17 times
# ('diabetes',) is used 7 times
# ('The',) is used 36 times
# ('greater',) is used 4 times
# ('intake',) is used 6 times
# ('least',) is used 5 times
# ('mg',) is used 4 times
# ('per',) is used 11 times
# ('High',) is used 4 times
# ('level',) is used 4 times
# ('cholesterol',) is used 7 times
# ('fat',) is used 5 times
# ('blood',) is used 24 times
# ('called',) is used 9 times
# ('amount',) is used 14 times
# ('cup',) is used 15 times
# ('decaffeinated',) is used 4 times
# ('effect',) is used 38 times
# ('pressure',) is used 12 times
# ('low',) is used 3 times
# ('cause',) is used 16 times
# ('chance',) is used 15 times
# ('unclear',) is used 3 times
# ('drinking',) is used 24 times
# ('linked',) is used 8 times
# ('There',) is used 8 times
# ('help',) is used 10 times
# ('dont',) is used 9 times
# ('artery',) is used 3 times
# ('early',) is used 4 times
# ('doesnt',) is used 3 times
# ('heartbeat',) is used 11 times
# ('Some',) is used 20 times
# ('suggests',) is used 12 times
# ('But',) is used 8 times
# ('research',) is used 15 times
# ('woman',) is used 6 times
# ('speed',) is used 5 times
# ('healthy',) is used 3 times
# ('rectal',) is used 3 times
# ('found',) is used 3 times
# ('depression',) is used 8 times
# ('endometrial',) is used 4 times
# ('high',) is used 5 times
# ('may',) is used 6 times
# ('serious',) is used 4 times
# ('skin',) is used 6 times
# ('When',) is used 3 times
# ('taken',) is used 7 times
# ('NAFLD',) is used 3 times
# ('weight',) is used 5 times
# ('loss',) is used 4 times
# ('taking',) is used 11 times
# ('mouth',) is used 4 times
# ('3',) is used 4 times
# ('prostate',) is used 4 times
# ('disorder',) is used 5 times
# ('rate',) is used 4 times
# ('effectiveness',) is used 3 times
# ('SAFE',) is used 3 times
# ('4',) is used 3 times
# ('nervousness',) is used 4 times
# ('increased',) is used 9 times
# ('side',) is used 21 times
# ('Caffeinated',) is used 3 times
# ('POSSIBLY',) is used 5 times
# ('UNSAFE',) is used 3 times
# ('large',) is used 3 times
# ('headache',) is used 8 times
# ('anxiety',) is used 4 times
# ('symptom',) is used 4 times
# ('get',) is used 21 times
# ('concern',) is used 4 times
# ('problem',) is used 4 times
# ('attack',) is used 3 times
# ('within',) is used 3 times
# ('including',) is used 10 times
# ('le',) is used 4 times
# ('pregnancy',) is used 3 times
# ('birth',) is used 4 times
# ('mother',) is used 3 times
# ('make',) is used 6 times
# ('worse',) is used 3 times
# ('sugar',) is used 7 times
# ('decrease',) is used 22 times
# ('especially',) is used 3 times
# ('osteoporosis',) is used 3 times
# ('calcium',) is used 4 times
# ('If',) is used 4 times
# ('Taking',) is used 14 times
# ('Interaction',) is used 3 times
# ('take',) is used 6 times
# ('combination',) is used 3 times
# ('interacts',) is used 28 times
# ('COFFEE',) is used 28 times
# ('Stimulant',) is used 3 times
# ('drug',) is used 10 times
# ('ephedrine',) is used 3 times
# ('stimulant',) is used 6 times
# ('much',) is used 8 times
# ('stimulation',) is used 3 times
# ('caffeinecontaining',) is used 3 times
# ('product',) is used 5 times
# ('Adenocard',) is used 3 times
# ('block',) is used 3 times
# ('test',) is used 8 times
# ('cardiac',) is used 4 times
# ('stress',) is used 4 times
# ('body',) is used 38 times
# ('break',) is used 23 times
# ('rid',) is used 20 times
# ('quickly',) is used 14 times
# ('along',) is used 11 times
# ('jitteriness',) is used 8 times
# ('fast',) is used 8 times
# ('Fosamax',) is used 5 times
# ('alendronate',) is used 4 times
# ('absorbs',) is used 3 times
# ('two',) is used 3 times
# ('antibiotic',) is used 4 times
# ('include',) is used 9 times
# ('Clozaril',) is used 5 times
# ('clozapine',) is used 4 times
# ('Persantine',) is used 3 times
# ('Antabuse',) is used 3 times
# ('others',) is used 13 times
# ('estrogen',) is used 4 times
# ('pill',) is used 7 times
# ('ethinyl',) is used 3 times
# ('estradiol',) is used 4 times
# ('Luvox',) is used 3 times
# ('levothyroxine',) is used 3 times
# ('lithium',) is used 4 times
# ('Medications',) is used 4 times
# ('stimulate',) is used 4 times
# ('medication',) is used 16 times
# ('avoid',) is used 4 times
# ('slow',) is used 4 times
# ('clotting',) is used 4 times
# ('Rilutek',) is used 3 times
# ('riluzole',) is used 3 times
# ('theophylline',) is used 4 times
# ('Calan',) is used 3 times
# ('Covera',) is used 3 times
# ('Isoptin',) is used 3 times
# ('Verelan',) is used 3 times
# ('control',) is used 4 times
# ('Tagamet',) is used 3 times
# ('Diflucan',) is used 3 times
# ('Mexiletine',) is used 3 times
# ('Mexitil',) is used 3 times

# %%
bigram1 = bigram(coffee)
# Out:
# ('drink', 'coffee') is used 25 times
# ('fatigue', 'increase') is used 2 times
# ('Coffee', 'also') is used 3 times
# ('prevent', 'Parkinson') is used 2 times
# ('Parkinson', 'disease') is used 4 times
# ('Coffee', 'enema') is used 2 times
# ('Gerson', 'Therapy') is used 2 times
# ('caffeinated', 'coffee') is used 11 times
# ('Coffee', 'contains') is used 6 times
# ('contains', 'caffeine') is used 4 times
# ('nervous', 'system') is used 5 times
# ('contains', 'chemical') is used 3 times
# ('Drinking', 'coffee') is used 9 times
# ('contain', 'caffeine') is used 2 times
# ('seems', 'increase') is used 2 times
# ('increase', 'alertness') is used 2 times
# ('Caffeine', 'also') is used 2 times
# ('coffee', 'might') is used 21 times
# ('People', 'drink') is used 14 times
# ('coffee', 'seem') is used 3 times
# ('seem', 'lower') is used 10 times
# ('lower', 'risk') is used 13 times
# ('risk', 'developing') is used 8 times
# ('The', 'greater') is used 2 times
# ('greater', 'intake') is used 2 times
# ('coffee', 'lower') is used 5 times
# ('disease', 'People') is used 2 times
# ('beverage', 'coffee') is used 2 times
# ('400', 'mg') is used 2 times
# ('mg', 'caffeine') is used 3 times
# ('per', 'day') is used 11 times
# ('day', 'seem') is used 2 times
# ('intake', 'caffeine') is used 2 times
# ('cholesterol', 'fat') is used 2 times
# ('Drinking', 'caffeinated') is used 5 times
# ('coffee', 'seems') is used 4 times
# ('total', 'cholesterol') is used 2 times
# ('blood', 'fat') is used 2 times
# ('fat', 'called') is used 2 times
# ('called', 'triglyceride') is used 2 times
# ('cup', 'caffeinated') is used 2 times
# ('coffee', 'per') is used 4 times
# ('day', 'might') is used 3 times
# ('decaffeinated', 'coffee') is used 4 times
# ('blood', 'pressure') is used 11 times
# ('pressure', 'Drinking') is used 2 times
# ('caffeinated', 'beverage') is used 2 times
# ('increase', 'blood') is used 3 times
# ('coffee', 'every') is used 2 times
# ('every', 'day') is used 2 times
# ('lower', 'chance') is used 11 times
# ('heart', 'disease') is used 6 times
# ('drinking', 'coffee') is used 16 times
# ('coffee', 'linked') is used 3 times
# ('linked', 'lower') is used 4 times
# ('There', 'evidence') is used 3 times
# ('people', 'drink') is used 9 times
# ('seem', 'help') is used 2 times
# ('help', 'prevent') is used 4 times
# ('coffee', 'dont') is used 7 times
# ('dont', 'seem') is used 7 times
# ('chance', 'developing') is used 8 times
# ('buildup', 'calciumcontaining') is used 2 times
# ('calciumcontaining', 'plaque') is used 2 times
# ('plaque', 'artery') is used 2 times
# ('coffee', 'doesnt') is used 3 times
# ('doesnt', 'seem') is used 3 times
# ('seem', 'linked') is used 2 times
# ('atrial', 'fibrillation') is used 2 times
# ('cancer', 'Some') is used 4 times
# ('Some', 'early') is used 2 times
# ('evidence', 'suggests') is used 2 times
# ('cancer', 'This') is used 2 times
# ('suggests', 'people') is used 2 times
# ('developing', 'bladder') is used 2 times
# ('bladder', 'cancer') is used 2 times
# ('cancer', 'But') is used 4 times
# ('But', 'research') is used 3 times
# ('research', 'suggests') is used 10 times
# ('cancer', 'People') is used 5 times
# ('thinking', 'skill') is used 2 times
# ('might', 'improve') is used 2 times
# ('improve', 'thinking') is used 2 times
# ('healthy', 'adult') is used 2 times
# ('rectal', 'cancer') is used 3 times
# ('colon', 'rectal') is used 2 times
# ('found', 'link') is used 2 times
# ('link', 'drinking') is used 2 times
# ('coffee', 'risk') is used 3 times
# ('might', 'lower') is used 5 times
# ('endometrial', 'cancer') is used 4 times
# ('cancer', 'The') is used 2 times
# ('The', 'effect') is used 3 times
# ('effect', 'coffee') is used 6 times
# ('risk', 'endometrial') is used 2 times
# ('Some', 'research') is used 6 times
# ('High', 'blood') is used 2 times
# ('high', 'blood') is used 4 times
# ('risk', 'liver') is used 2 times
# ('liver', 'disease') is used 2 times
# ('suggests', 'drinking') is used 5 times
# ('coffee', 'may') is used 2 times
# ('may', 'help') is used 3 times
# ('prevent', 'lung') is used 2 times
# ('lung', 'cancer') is used 2 times
# ('skin', 'cancer') is used 6 times
# ('weight', 'loss') is used 4 times
# ('chemical', 'called') is used 3 times
# ('help', 'weight') is used 3 times
# ('men', 'woman') is used 2 times
# ('roast', 'coffee') is used 2 times
# ('help', 'reduce') is used 2 times
# ('3', 'cup') is used 4 times
# ('cup', 'coffee') is used 6 times
# ('pharyngeal', 'cancer') is used 2 times
# ('prostate', 'cancer') is used 3 times
# ('might', 'reduce') is used 2 times
# ('form', 'skin') is used 2 times
# ('effect', 'skin') is used 2 times
# ('caffeine', 'coffee') is used 24 times
# ('taken', 'mouth') is used 3 times
# ('4', 'cup') is used 3 times
# ('cup', 'per') is used 5 times
# ('increased', 'heart') is used 3 times
# ('rate', 'side') is used 2 times
# ('side', 'effect') is used 20 times
# ('Drinking', 'unfiltered') is used 2 times
# ('coffee', 'increase') is used 7 times
# ('This', 'might') is used 2 times
# ('might', 'increase') is used 10 times
# ('increase', 'risk') is used 7 times
# ('developing', 'heart') is used 3 times
# ('Caffeinated', 'coffee') is used 3 times
# ('coffee', 'POSSIBLY') is used 3 times
# ('POSSIBLY', 'UNSAFE') is used 3 times
# ('large', 'amount') is used 3 times
# ('might', 'cause') is used 8 times
# ('anxiety', 'agitation') is used 2 times
# ('cup', 'daily') is used 2 times
# ('coffee', 'get') is used 10 times
# ('There', 'concern') is used 3 times
# ('concern', 'drinking') is used 2 times
# ('But', 'people') is used 2 times
# ('seem', 'increase') is used 2 times
# ('increase', 'chance') is used 3 times
# ('heart', 'problem') is used 2 times
# ('heart', 'attack') is used 3 times
# ('increased', 'risk') is used 3 times
# ('risk', 'type') is used 2 times
# ('type', 'cancer') is used 2 times
# ('effect', 'including') is used 6 times
# ('POSSIBLY', 'SAFE') is used 2 times
# ('day', 'le') is used 2 times
# ('amount', 'coffee') is used 2 times
# ('300', 'mg') is used 2 times
# ('increase', 'amount') is used 3 times
# ('nursing', 'mother') is used 2 times
# ('caffeine', 'intake') is used 2 times
# ('disorder', 'The') is used 2 times
# ('The', 'caffeine') is used 13 times
# ('might', 'make') is used 3 times
# ('blood', 'sugar') is used 6 times
# ('caffeine', 'The') is used 3 times
# ('coffee', 'especially') is used 2 times
# ('especially', 'taken') is used 2 times
# ('taken', 'large') is used 2 times
# ('worsen', 'diarrhea') is used 2 times
# ('limit', 'caffeine') is used 2 times
# ('Do', 'take') is used 2 times
# ('interacts', 'COFFEE') is used 28 times
# ('COFFEE', 'Stimulant') is used 2 times
# ('Stimulant', 'drug') is used 3 times
# ('drug', 'speed') is used 2 times
# ('speed', 'nervous') is used 3 times
# ('stimulant', 'drug') is used 4 times
# ('coffee', 'taking') is used 4 times
# ('cause', 'much') is used 5 times
# ('much', 'stimulation') is used 3 times
# ('serious', 'side') is used 2 times
# ('caffeinecontaining', 'product') is used 3 times
# ('Interaction', 'Be') is used 2 times
# ('Adenosine', 'Adenocard') is used 2 times
# ('COFFEE', 'The') is used 18 times
# ('might', 'block') is used 2 times
# ('block', 'affect') is used 2 times
# ('often', 'used') is used 2 times
# ('used', 'doctor') is used 2 times
# ('doctor', 'test') is used 2 times
# ('test', 'heart') is used 2 times
# ('heart', 'This') is used 2 times
# ('This', 'test') is used 2 times
# ('test', 'called') is used 2 times
# ('called', 'cardiac') is used 2 times
# ('cardiac', 'stress') is used 4 times
# ('stress', 'test') is used 4 times
# ('test', 'Stop') is used 2 times
# ('coffee', 'caffeinecontaining') is used 2 times
# ('product', 'least') is used 2 times
# ('least', '24') is used 2 times
# ('24', 'hour') is used 2 times
# ('hour', 'cardiac') is used 2 times
# ('The', 'body') is used 13 times
# ('body', 'break') is used 23 times
# ('break', 'caffeine') is used 19 times
# ('get', 'rid') is used 20 times
# ('decrease', 'quickly') is used 12 times
# ('quickly', 'body') is used 13 times
# ('caffeine', 'Taking') is used 9 times
# ('Taking', 'coffee') is used 6 times
# ('coffee', 'along') is used 6 times
# ('much', 'caffeine') is used 2 times
# ('caffeine', 'side') is used 2 times
# ('including', 'jitteriness') is used 6 times
# ('jitteriness', 'headache') is used 7 times
# ('headache', 'fast') is used 4 times
# ('fast', 'heartbeat') is used 5 times
# ('COFFEE', 'Coffee') is used 6 times
# ('decrease', 'much') is used 3 times
# ('alendronate', 'Fosamax') is used 4 times
# ('body', 'absorbs') is used 3 times
# ('decrease', 'effectiveness') is used 2 times
# ('two', 'hour') is used 3 times
# ('hour', 'taking') is used 3 times
# ('caffeine', 'get') is used 2 times
# ('Some', 'antibiotic') is used 2 times
# ('might', 'decrease') is used 4 times
# ('along', 'coffee') is used 4 times
# ('risk', 'side') is used 3 times
# ('headache', 'increased') is used 3 times
# ('heart', 'rate') is used 2 times
# ('effect', 'Some') is used 2 times
# ('break', 'clozapine') is used 2 times
# ('clozapine', 'Clozaril') is used 4 times
# ('decrease', 'fast') is used 3 times
# ('fast', 'body') is used 3 times
# ('increase', 'effect') is used 6 times
# ('effect', 'side') is used 7 times
# ('Dipyridamole', 'Persantine') is used 2 times
# ('Disulfiram', 'Antabuse') is used 2 times
# ('body', 'get') is used 6 times
# ('rid', 'caffeine') is used 4 times
# ('coffee', 'including') is used 3 times
# ('estrogen', 'pill') is used 3 times
# ('cause', 'jitteriness') is used 2 times
# ('heartbeat', 'side') is used 2 times
# ('If', 'take') is used 2 times
# ('pill', 'include') is used 2 times
# ('ethinyl', 'estradiol') is used 3 times
# ('Fluvoxamine', 'Luvox') is used 2 times
# ('Taking', 'caffeine') is used 2 times
# ('effect', 'caffeine') is used 2 times
# ('rid', 'lithium') is used 2 times
# ('Medications', 'depression') is used 2 times
# ('coffee', 'stimulate') is used 2 times
# ('stimulate', 'body') is used 4 times
# ('Some', 'medication') is used 5 times
# ('medication', 'used') is used 4 times
# ('used', 'depression') is used 2 times
# ('also', 'stimulate') is used 2 times
# ('taking', 'medication') is used 2 times
# ('medication', 'depression') is used 3 times
# ('depression', 'include') is used 2 times
# ('called', 'tannin') is used 2 times
# ('tannin', 'Tannins') is used 2 times
# ('Tannins', 'bind') is used 2 times
# ('bind', 'many') is used 2 times
# ('many', 'medication') is used 2 times
# ('medication', 'decrease') is used 2 times
# ('much', 'medicine') is used 2 times
# ('medicine', 'body') is used 2 times
# ('absorbs', 'To') is used 2 times
# ('To', 'avoid') is used 2 times
# ('avoid', 'interaction') is used 2 times
# ('interaction', 'avoid') is used 2 times
# ('avoid', 'coffee') is used 2 times
# ('coffee', 'one') is used 2 times
# ('one', 'hour') is used 2 times
# ('hour', 'two') is used 2 times
# ('slow', 'blood') is used 3 times
# ('blood', 'clotting') is used 3 times
# ('drug', 'interacts') is used 4 times
# ('Coffee', 'might') is used 2 times
# ('phenothiazine', 'medication') is used 2 times
# ('break', 'riluzole') is used 2 times
# ('riluzole', 'Rilutek') is used 2 times
# ('Verapamil', 'Calan') is used 2 times
# ('Calan', 'Covera') is used 3 times
# ('Covera', 'Isoptin') is used 3 times
# ('Isoptin', 'Verelan') is used 3 times
# ('increased', 'heartbeat') is used 2 times
# ('Birth', 'control') is used 2 times
# ('control', 'pill') is used 4 times
# ('birth', 'control') is used 2 times
# ('Cimetidine', 'Tagamet') is used 2 times
# ('Fluconazole', 'Diflucan') is used 2 times
# ('diabetes', 'medication') is used 2 times
# ('Mexiletine', 'Mexitil') is used 3 times
# ('Terbinafine', 'Lamisil') is used 2 times

# %%
trigram1 = trigram(coffee)
# Out:
# ('prevent', 'Parkinson', 'disease') is used 2 times
# ('Coffee', 'contains', 'caffeine') is used 4 times
# ('People', 'drink', 'coffee') is used 13 times
# ('seem', 'lower', 'risk') is used 6 times
# ('lower', 'risk', 'developing') is used 5 times
# ('The', 'greater', 'intake') is used 2 times
# ('coffee', 'lower', 'risk') is used 3 times
# ('disease', 'People', 'drink') is used 2 times
# ('400', 'mg', 'caffeine') is used 2 times
# ('day', 'seem', 'lower') is used 2 times
# ('Drinking', 'caffeinated', 'coffee') is used 4 times
# ('caffeinated', 'coffee', 'seems') is used 2 times
# ('blood', 'fat', 'called') is used 2 times
# ('fat', 'called', 'triglyceride') is used 2 times
# ('cup', 'caffeinated', 'coffee') is used 2 times
# ('coffee', 'per', 'day') is used 4 times
# ('per', 'day', 'might') is used 3 times
# ('blood', 'pressure', 'Drinking') is used 2 times
# ('pressure', 'Drinking', 'caffeinated') is used 2 times
# ('increase', 'blood', 'pressure') is used 2 times
# ('coffee', 'every', 'day') is used 2 times
# ('seem', 'lower', 'chance') is used 4 times
# ('drinking', 'coffee', 'linked') is used 3 times
# ('coffee', 'linked', 'lower') is used 2 times
# ('linked', 'lower', 'chance') is used 2 times
# ('coffee', 'seem', 'help') is used 2 times
# ('seem', 'help', 'prevent') is used 2 times
# ('drink', 'coffee', 'dont') is used 7 times
# ('coffee', 'dont', 'seem') is used 7 times
# ('dont', 'seem', 'lower') is used 7 times
# ('lower', 'chance', 'developing') is used 7 times
# ('buildup', 'calciumcontaining', 'plaque') is used 2 times
# ('calciumcontaining', 'plaque', 'artery') is used 2 times
# ('coffee', 'doesnt', 'seem') is used 3 times
# ('doesnt', 'seem', 'linked') is used 2 times
# ('seem', 'linked', 'lower') is used 2 times
# ('people', 'drink', 'coffee') is used 6 times
# ('drink', 'coffee', 'lower') is used 4 times
# ('suggests', 'people', 'drink') is used 2 times
# ('coffee', 'lower', 'chance') is used 2 times
# ('developing', 'bladder', 'cancer') is used 2 times
# ('cancer', 'But', 'research') is used 3 times
# ('drink', 'coffee', 'might') is used 5 times
# ('cancer', 'People', 'drink') is used 5 times
# ('might', 'improve', 'thinking') is used 2 times
# ('colon', 'rectal', 'cancer') is used 2 times
# ('found', 'link', 'drinking') is used 2 times
# ('link', 'drinking', 'coffee') is used 2 times
# ('drinking', 'coffee', 'risk') is used 2 times
# ('coffee', 'might', 'lower') is used 4 times
# ('might', 'lower', 'chance') is used 3 times
# ('The', 'effect', 'coffee') is used 2 times
# ('coffee', 'risk', 'endometrial') is used 2 times
# ('risk', 'endometrial', 'cancer') is used 2 times
# ('Some', 'research', 'suggests') is used 5 times
# ('High', 'blood', 'pressure') is used 2 times
# ('high', 'blood', 'pressure') is used 4 times
# ('might', 'lower', 'risk') is used 2 times
# ('lower', 'risk', 'liver') is used 2 times
# ('cancer', 'Some', 'research') is used 2 times
# ('research', 'suggests', 'drinking') is used 5 times
# ('coffee', 'may', 'help') is used 2 times
# ('may', 'help', 'prevent') is used 2 times
# ('help', 'prevent', 'lung') is used 2 times
# ('prevent', 'lung', 'cancer') is used 2 times
# ('suggests', 'drinking', 'coffee') is used 2 times
# ('help', 'weight', 'loss') is used 3 times
# ('cup', 'coffee', 'per') is used 3 times
# ('form', 'skin', 'cancer') is used 2 times
# ('effect', 'skin', 'cancer') is used 2 times
# ('4', 'cup', 'per') is used 2 times
# ('cup', 'per', 'day') is used 5 times
# ('rate', 'side', 'effect') is used 2 times
# ('might', 'increase', 'risk') is used 2 times
# ('risk', 'developing', 'heart') is used 2 times
# ('developing', 'heart', 'disease') is used 2 times
# ('Caffeinated', 'coffee', 'POSSIBLY') is used 3 times
# ('caffeinated', 'coffee', 'might') is used 2 times
# ('There', 'concern', 'drinking') is used 2 times
# ('drinking', 'coffee', 'might') is used 2 times
# ('coffee', 'might', 'increase') is used 5 times
# ('increase', 'risk', 'type') is used 2 times
# ('risk', 'type', 'cancer') is used 2 times
# ('coffee', 'increase', 'risk') is used 2 times
# ('side', 'effect', 'including') is used 6 times
# ('coffee', 'POSSIBLY', 'SAFE') is used 2 times
# ('3', 'cup', 'per') is used 2 times
# ('per', 'day', 'le') is used 2 times
# ('disorder', 'The', 'caffeine') is used 2 times
# ('The', 'caffeine', 'coffee') is used 13 times
# ('caffeine', 'coffee', 'might') is used 5 times
# ('coffee', 'might', 'make') is used 3 times
# ('coffee', 'increase', 'amount') is used 2 times
# ('contains', 'caffeine', 'The') is used 3 times
# ('caffeine', 'The', 'caffeine') is used 2 times
# ('caffeine', 'coffee', 'especially') is used 2 times
# ('coffee', 'especially', 'taken') is used 2 times
# ('especially', 'taken', 'large') is used 2 times
# ('taken', 'large', 'amount') is used 2 times
# ('caffeinated', 'coffee', 'increase') is used 2 times
# ('might', 'increase', 'blood') is used 2 times
# ('interacts', 'COFFEE', 'Stimulant') is used 2 times
# ('COFFEE', 'Stimulant', 'drug') is used 2 times
# ('Stimulant', 'drug', 'speed') is used 2 times
# ('drug', 'speed', 'nervous') is used 2 times
# ('speed', 'nervous', 'system') is used 3 times
# ('Drinking', 'coffee', 'taking') is used 4 times
# ('might', 'cause', 'much') is used 5 times
# ('cause', 'much', 'stimulation') is used 3 times
# ('serious', 'side', 'effect') is used 2 times
# ('interacts', 'COFFEE', 'The') is used 18 times
# ('COFFEE', 'The', 'caffeine') is used 5 times
# ('coffee', 'might', 'block') is used 2 times
# ('might', 'block', 'affect') is used 2 times
# ('often', 'used', 'doctor') is used 2 times
# ('used', 'doctor', 'test') is used 2 times
# ('doctor', 'test', 'heart') is used 2 times
# ('test', 'heart', 'This') is used 2 times
# ('heart', 'This', 'test') is used 2 times
# ('This', 'test', 'called') is used 2 times
# ('test', 'called', 'cardiac') is used 2 times
# ('called', 'cardiac', 'stress') is used 2 times
# ('cardiac', 'stress', 'test') is used 4 times
# ('stress', 'test', 'Stop') is used 2 times
# ('coffee', 'caffeinecontaining', 'product') is used 2 times
# ('caffeinecontaining', 'product', 'least') is used 2 times
# ('product', 'least', '24') is used 2 times
# ('least', '24', 'hour') is used 2 times
# ('24', 'hour', 'cardiac') is used 2 times
# ('hour', 'cardiac', 'stress') is used 2 times
# ('COFFEE', 'The', 'body') is used 12 times
# ('The', 'body', 'break') is used 13 times
# ('body', 'break', 'caffeine') is used 19 times
# ('break', 'caffeine', 'coffee') is used 9 times
# ('caffeine', 'coffee', 'get') is used 9 times
# ('coffee', 'get', 'rid') is used 9 times
# ('decrease', 'quickly', 'body') is used 12 times
# ('quickly', 'body', 'break') is used 8 times
# ('break', 'caffeine', 'Taking') is used 7 times
# ('caffeine', 'Taking', 'coffee') is used 3 times
# ('Taking', 'coffee', 'along') is used 5 times
# ('cause', 'much', 'caffeine') is used 2 times
# ('caffeine', 'side', 'effect') is used 2 times
# ('effect', 'including', 'jitteriness') is used 4 times
# ('including', 'jitteriness', 'headache') is used 5 times
# ('jitteriness', 'headache', 'fast') is used 4 times
# ('headache', 'fast', 'heartbeat') is used 4 times
# ('interacts', 'COFFEE', 'Coffee') is used 6 times
# ('two', 'hour', 'taking') is used 3 times
# ('break', 'caffeine', 'get') is used 2 times
# ('caffeine', 'get', 'rid') is used 2 times
# ('might', 'decrease', 'quickly') is used 2 times
# ('increase', 'risk', 'side') is used 3 times
# ('risk', 'side', 'effect') is used 3 times
# ('jitteriness', 'headache', 'increased') is used 3 times
# ('increased', 'heart', 'rate') is used 2 times
# ('side', 'effect', 'Some') is used 2 times
# ('body', 'break', 'clozapine') is used 2 times
# ('break', 'clozapine', 'Clozaril') is used 2 times
# ('coffee', 'might', 'decrease') is used 2 times
# ('decrease', 'fast', 'body') is used 3 times
# ('fast', 'body', 'break') is used 2 times
# ('increase', 'effect', 'side') is used 6 times
# ('effect', 'side', 'effect') is used 7 times
# ('quickly', 'body', 'get') is used 5 times
# ('body', 'get', 'rid') is used 6 times
# ('get', 'rid', 'caffeine') is used 4 times
# ('rid', 'caffeine', 'Taking') is used 2 times
# ('might', 'increase', 'effect') is used 3 times
# ('side', 'effect', 'coffee') is used 4 times
# ('effect', 'coffee', 'including') is used 3 times
# ('coffee', 'including', 'jitteriness') is used 2 times
# ('cause', 'jitteriness', 'headache') is used 2 times
# ('fast', 'heartbeat', 'side') is used 2 times
# ('heartbeat', 'side', 'effect') is used 2 times
# ('get', 'rid', 'lithium') is used 2 times
# ('caffeine', 'coffee', 'stimulate') is used 2 times
# ('coffee', 'stimulate', 'body') is used 2 times
# ('Some', 'medication', 'used') is used 3 times
# ('medication', 'used', 'depression') is used 2 times
# ('also', 'stimulate', 'body') is used 2 times
# ('taking', 'medication', 'depression') is used 2 times
# ('COFFEE', 'Coffee', 'contains') is used 3 times
# ('Coffee', 'contains', 'chemical') is used 2 times
# ('contains', 'chemical', 'called') is used 2 times
# ('chemical', 'called', 'tannin') is used 2 times
# ('called', 'tannin', 'Tannins') is used 2 times
# ('tannin', 'Tannins', 'bind') is used 2 times
# ('Tannins', 'bind', 'many') is used 2 times
# ('bind', 'many', 'medication') is used 2 times
# ('many', 'medication', 'decrease') is used 2 times
# ('medication', 'decrease', 'much') is used 2 times
# ('decrease', 'much', 'medicine') is used 2 times
# ('much', 'medicine', 'body') is used 2 times
# ('medicine', 'body', 'absorbs') is used 2 times
# ('body', 'absorbs', 'To') is used 2 times
# ('absorbs', 'To', 'avoid') is used 2 times
# ('To', 'avoid', 'interaction') is used 2 times
# ('avoid', 'interaction', 'avoid') is used 2 times
# ('interaction', 'avoid', 'coffee') is used 2 times
# ('avoid', 'coffee', 'one') is used 2 times
# ('coffee', 'one', 'hour') is used 2 times
# ('one', 'hour', 'two') is used 2 times
# ('hour', 'two', 'hour') is used 2 times
# ('slow', 'blood', 'clotting') is used 3 times
# ('drug', 'interacts', 'COFFEE') is used 4 times
# ('COFFEE', 'Coffee', 'might') is used 2 times
# ('might', 'increase', 'chance') is used 2 times
# ('body', 'break', 'riluzole') is used 2 times
# ('break', 'riluzole', 'Rilutek') is used 2 times
# ('Verapamil', 'Calan', 'Covera') is used 2 times
# ('Calan', 'Covera', 'Isoptin') is used 3 times
# ('Covera', 'Isoptin', 'Verelan') is used 3 times
# ('headache', 'increased', 'heartbeat') is used 2 times
# ('Birth', 'control', 'pill') is used 2 times
# ('birth', 'control', 'pill') is used 2 times
# ('along', 'coffee', 'might') is used 2 times

# %%
POStag = tagging(coffee)
# Out:
# Counter({'NN': 1055, 'IN': 440, 'JJ': 313, 'NNS': 303, 'DT': 285, '.': 262, 'VB': 204, ',': 156, 'VBZ': 143, 'CC': 132, 'RB': 121, 'VBG': 114, '(': 107, ')': 107, 'MD': 95, 'VBP': 89, 'TO': 75, 'VBN': 72, 'JJR': 63, 'WRB': 34, 'CD': 32, 'WP': 32, 'PRP': 31, 'RP': 29, 'VBD': 20, ':': 16, 'WDT': 13, 'FW': 13, 'EX': 10, 'PRP$': 8, 'JJS': 7, '``': 4, "''": 4, 'UH': 3, 'RBS': 2, 'RBR': 2, 'NNP': 1})

# %%
f=open(r"C:\Users\SEHER\OneDrive\Masaüstü\covid-19.txt","r")
covid =f.read()

# %%
words =clean(covid)
words
# Out:
# ['Coronavirus',
#  'disease',
#  '2019',
#  'COVID19',
#  'contagious',
#  'respiratory',
#  'vascular',
#  'disease',
#  'caused',
#  'severe',
#  'acute',
#  'respiratory',
#  'syndrome',
#  'coronavirus',
#  '2',
#  'SARSCoV2',
#  'The',
#  'first',
#  'case',
#  'identified',
#  'Wuhan',
#  'China',
#  'December',
#  '2019',
#  'though',
#  'evidence',
#  'suggests',
#  'virus',
#  'may',
#  'actively',
#  'spreading',
#  'month',
#  'earlier',
#  'Common',
#  'symptom',
#  'COVID19',
#  'include',
#  'fever',
#  'cough',
#  'fatigue',
#  'breathing',
#  'difficulty',
#  'loss',
#  'smell',
#  'tasteSymptoms',
#  'begin',
#  'one',
#  'fourteen',
#  'day',
#  'exposure',
#  'virus',
#  'While',
#  'people',
#  'mild',
#  'symptom',
#  'people',
#  'develop',
#  'acute',
#  'respiratory',
#  'distress',
#  'syndrome',
#  'ARDS',
#  'ARDS',
#  'precipitated',
#  'cytokine',
#  'storm',
#  'multiorgan',
#  'failure',
#  'septic',
#  'shock',
#  'blood',
#  'clot',
#  'Longerterm',
#  'damage',
#  'organ',
#  'particular',
#  'lung',
#  'heart',
#  'observed',
#  'There',
#  'concern',
#  'significant',
#  'number',
#  'patient',
#  'recovered',
#  'acute',
#  'phase',
#  'disease',
#  'continue',
#  'experience',
#  'range',
#  'effectsâknown',
#  'long',
#  'COVIDâfor',
#  'month',
#  'afterwards',
#  'These',
#  'effect',
#  'include',
#  'severe',
#  'fatigue',
#  'memory',
#  'loss',
#  'cognitive',
#  'issue',
#  'low',
#  'grade',
#  'fever',
#  'muscle',
#  'weakness',
#  'breathlessness',
#  'COVID19',
#  'spread',
#  'via',
#  'number',
#  'mean',
#  'primarily',
#  'involving',
#  'saliva',
#  'bodily',
#  'fluid',
#  'excretion',
#  'These',
#  'fluid',
#  'form',
#  'small',
#  'droplet',
#  'aerosol',
#  'spread',
#  'infected',
#  'person',
#  'breathes',
#  'cough',
#  'sneeze',
#  'sings',
#  'speaks',
#  'This',
#  'suspected',
#  'main',
#  'mode',
#  'transmission',
#  'The',
#  'virus',
#  'may',
#  'also',
#  'spread',
#  'via',
#  'fomite',
#  'contaminated',
#  'surface',
#  'direct',
#  'contactInfection',
#  'mainly',
#  'happens',
#  'people',
#  'near',
#  'long',
#  'enoughIt',
#  'spread',
#  'early',
#  'two',
#  'day',
#  'infected',
#  'person',
#  'show',
#  'symptom',
#  'presymptomatic',
#  'asymptomatic',
#  'symptom',
#  'individual',
#  'People',
#  'remain',
#  'infectious',
#  'ten',
#  'day',
#  'moderate',
#  'case',
#  'two',
#  'week',
#  'severe',
#  'case',
#  'The',
#  'standard',
#  'diagnosis',
#  'method',
#  'realtime',
#  'reverse',
#  'transcription',
#  'polymerase',
#  'chain',
#  'reaction',
#  'rRTPCR',
#  'nasopharyngeal',
#  'swab',
#  'Preventive',
#  'measure',
#  'include',
#  'social',
#  'distancing',
#  'quarantining',
#  'ventilation',
#  'indoor',
#  'space',
#  'covering',
#  'cough',
#  'sneeze',
#  'hand',
#  'washing',
#  'keeping',
#  'unwashed',
#  'hand',
#  'away',
#  'face',
#  'The',
#  'use',
#  'face',
#  'mask',
#  'covering',
#  'recommended',
#  'public',
#  'setting',
#  'minimise',
#  'risk',
#  'transmission',
#  'There',
#  'currently',
#  'proven',
#  'vaccine',
#  'specific',
#  'treatment',
#  'COVID19',
#  'though',
#  'several',
#  'development',
#  'Management',
#  'involves',
#  'treatment',
#  'symptom',
#  'supportive',
#  'care',
#  'isolation',
#  'experimental',
#  'measure',
#  'Signs',
#  'symptom',
#  'Main',
#  'article',
#  'Symptoms',
#  'COVID19',
#  'Symptoms',
#  'COVID19',
#  'Symptoms',
#  'COVID19',
#  'variable',
#  'usually',
#  'include',
#  'fever',
#  'cough',
#  'People',
#  'infection',
#  'may',
#  'different',
#  'symptom',
#  'symptom',
#  'may',
#  'change',
#  'time',
#  'For',
#  'example',
#  'one',
#  'person',
#  'may',
#  'high',
#  'fever',
#  'cough',
#  'fatigue',
#  'another',
#  'person',
#  'may',
#  'low',
#  'fever',
#  'start',
#  'disease',
#  'develop',
#  'difficulty',
#  'breathing',
#  'week',
#  'later',
#  'However',
#  'people',
#  'without',
#  'prior',
#  'ear',
#  'nose',
#  'throat',
#  'ENT',
#  'disorder',
#  'loss',
#  'taste',
#  'combined',
#  'loss',
#  'smell',
#  'associated',
#  'COVID19',
#  'specificity',
#  '95',
#  'Some',
#  'symptom',
#  'COVID19',
#  'relatively',
#  'nonspecific',
#  'two',
#  'common',
#  'symptom',
#  'fever',
#  '88',
#  'percent',
#  'dry',
#  'cough',
#  '68',
#  'percent',
#  'Among',
#  'develop',
#  'symptom',
#  'approximately',
#  'one',
#  'five',
#  'may',
#  'become',
#  'seriously',
#  'ill',
#  'difficulty',
#  'breathing',
#  'Emergency',
#  'symptom',
#  'include',
#  'difficulty',
#  'breathing',
#  'persistent',
#  'chest',
#  'pain',
#  'pressure',
#  'sudden',
#  'confusion',
#  'difficulty',
#  'waking',
#  'bluish',
#  'face',
#  'lip',
#  'immediate',
#  'medical',
#  'attention',
#  'advised',
#  'symptom',
#  'present28',
#  'Further',
#  'development',
#  'disease',
#  'lead',
#  'complication',
#  'including',
#  'pneumonia',
#  'acute',
#  'respiratory',
#  'distress',
#  'syndrome',
#  'sepsis',
#  'septic',
#  'shock',
#  'kidney',
#  'failure',
#  'As',
#  'common',
#  'infection',
#  'delay',
#  'known',
#  'incubation',
#  'period',
#  'moment',
#  'person',
#  'first',
#  'becomes',
#  'infected',
#  'appearance',
#  'first',
#  'symptom',
#  'The',
#  'median',
#  'incubation',
#  'period',
#  'COVID19',
#  'four',
#  'five',
#  'day',
#  'Most',
#  'symptomatic',
#  'people',
#  'experience',
#  'symptom',
#  'within',
#  'two',
#  'seven',
#  'day',
#  'exposure',
#  'almost',
#  'symptomatic',
#  'people',
#  'experience',
#  'one',
#  'symptom',
#  'day',
#  'twelve',
#  'Cause',
#  'COVID19',
#  'caused',
#  'infection',
#  'severe',
#  'acute',
#  'respiratory',
#  'syndrome',
#  'coronavirus',
#  '2',
#  'SARSCoV2',
#  'virus',
#  'strain',
#  'Transmission',
#  'Main',
#  'article',
#  'Transmission',
#  'COVID19',
#  'COVID19',
#  'spread',
#  'person',
#  'person',
#  'mainly',
#  'respiratory',
#  'route',
#  'infected',
#  'person',
#  'cough',
#  'sneeze',
#  'sings',
#  'talk',
#  'breathes',
#  'A',
#  'new',
#  'infection',
#  'occurs',
#  'viruscontaining',
#  'particle',
#  'exhaled',
#  'infected',
#  'person',
#  'either',
#  'respiratory',
#  'droplet',
#  'aerosol',
#  'get',
#  'mouth',
#  'nose',
#  'eye',
#  'people',
#  'close',
#  'contact',
#  'infected',
#  'person',
#  'Respiratory',
#  'droplet',
#  'may',
#  'evaporate',
#  'droplet',
#  'nucleus',
#  'remain',
#  'suspended',
#  'air',
#  'prolonged',
#  'period',
#  'time',
#  'Long',
#  'distance',
#  'airborne',
#  'transmission',
#  'shown',
#  'occur',
#  'hospital',
#  'ward',
#  'Airborne',
#  'transmission',
#  'demonstrated',
#  'healthcare',
#  'setting',
#  'certain',
#  'aerosolgenerating',
#  'medical',
#  'procedure',
#  'performed',
#  'COVID19',
#  'patient',
#  'regularly',
#  'occurs',
#  'crowded',
#  'inadequately',
#  'ventilated',
#  'indoor',
#  'space',
#  'restaurant',
#  'nightclub',
#  'choir',
#  'Kissing',
#  'physical',
#  'intimacy',
#  'form',
#  'direct',
#  'contact',
#  'easily',
#  'transmit',
#  'virus',
#  'thus',
#  'lead',
#  'COVID19',
#  'people',
#  'exposed',
#  'contact',
#  'A',
#  'person',
#  'get',
#  'COVID19',
#  'indirect',
#  'contact',
#  'touching',
#  'contaminated',
#  'surface',
#  'object',
#  'touching',
#  'mouth',
#  'nose',
#  'eyesthough',
#  'thought',
#  'main',
#  'way',
#  'virus',
#  'spread',
#  'There',
#  'currently',
#  'significant',
#  'evidence',
#  'COVID19',
#  'virus',
#  'transmission',
#  'feces',
#  'urine',
#  'breast',
#  'milk',
#  'food',
#  'wastewater',
#  'drinking',
#  'water',
#  'animal',
#  'disease',
#  'vector',
#  'mother',
#  'baby',
#  'pregnancy',
#  'although',
#  'research',
#  'ongoing',
#  'caution',
#  'advised',
#  'The',
#  'number',
#  'people',
#  'generally',
#  'infected',
#  'one',
#  'infected',
#  'person',
#  'varies',
#  'September',
#  '2020',
#  'estimated',
#  'one',
#  'infected',
#  'person',
#  'average',
#  'infect',
#  'two',
#  'three',
#  'people',
#  'This',
#  'infectious',
#  'influenza',
#  'le',
#  'measles',
#  'It',
#  'often',
#  'spread',
#  'cluster',
#  'infection',
#  'traced',
#  'back',
#  'index',
#  'case',
#  'geographical',
#  'location',
#  'There',
#  'major',
#  'role',
#  'superspreading',
#  'event',
#  'many',
#  'people',
#  'infected',
#  'one',
#  'person',
#  'It',
#  'transmitted',
#  'early',
#  'two',
#  'day',
#  'developing',
#  'symptom',
#  'even',
#  'symptom',
#  'never',
#  'appearPeople',
#  'remain',
#  'infectious',
#  'moderate',
#  'case',
#  '7â12',
#  'day',
#  'two',
#  'week',
#  'severe',
#  'case',
#  'In',
#  'October',
#  '2020',
#  'medical',
#  'scientist',
#  'reported',
#  'evidence',
#  'reinfection',
#  'one',
#  'patient']

# %%
unigram2 =unigram(covid)
# Out:
# ('disease',) is used 6 times
# ('COVID19',) is used 17 times
# ('respiratory',) is used 7 times
# ('severe',) is used 5 times
# ('acute',) is used 5 times
# ('syndrome',) is used 4 times
# ('The',) is used 6 times
# ('first',) is used 3 times
# ('case',) is used 6 times
# ('evidence',) is used 3 times
# ('virus',) is used 7 times
# ('may',) is used 8 times
# ('symptom',) is used 18 times
# ('include',) is used 5 times
# ('fever',) is used 6 times
# ('cough',) is used 7 times
# ('fatigue',) is used 3 times
# ('breathing',) is used 4 times
# ('difficulty',) is used 5 times
# ('loss',) is used 4 times
# ('one',) is used 8 times
# ('day',) is used 8 times
# ('people',) is used 11 times
# ('develop',) is used 3 times
# ('There',) is used 4 times
# ('number',) is used 3 times
# ('patient',) is used 3 times
# ('experience',) is used 3 times
# ('spread',) is used 7 times
# ('droplet',) is used 4 times
# ('infected',) is used 10 times
# ('person',) is used 14 times
# ('sneeze',) is used 3 times
# ('transmission',) is used 5 times
# ('two',) is used 7 times
# ('remain',) is used 3 times
# ('infectious',) is used 3 times
# ('week',) is used 3 times
# ('face',) is used 3 times
# ('Symptoms',) is used 3 times
# ('infection',) is used 5 times
# ('nose',) is used 3 times
# ('medical',) is used 3 times
# ('period',) is used 3 times
# ('contact',) is used 4 times

# %%
bigram2 =bigram(covid)
# Out:
# ('severe', 'acute') is used 2 times
# ('acute', 'respiratory') is used 4 times
# ('respiratory', 'syndrome') is used 2 times
# ('syndrome', 'coronavirus') is used 2 times
# ('coronavirus', '2') is used 2 times
# ('2', 'SARSCoV2') is used 2 times
# ('virus', 'may') is used 2 times
# ('symptom', 'COVID19') is used 2 times
# ('include', 'fever') is used 2 times
# ('fever', 'cough') is used 3 times
# ('cough', 'fatigue') is used 2 times
# ('loss', 'smell') is used 2 times
# ('day', 'exposure') is used 2 times
# ('respiratory', 'distress') is used 2 times
# ('distress', 'syndrome') is used 2 times
# ('septic', 'shock') is used 2 times
# ('COVID19', 'spread') is used 2 times
# ('spread', 'via') is used 2 times
# ('droplet', 'aerosol') is used 2 times
# ('infected', 'person') is used 7 times
# ('cough', 'sneeze') is used 3 times
# ('sneeze', 'sings') is used 2 times
# ('contaminated', 'surface') is used 2 times
# ('early', 'two') is used 2 times
# ('two', 'day') is used 2 times
# ('remain', 'infectious') is used 2 times
# ('moderate', 'case') is used 2 times
# ('two', 'week') is used 2 times
# ('week', 'severe') is used 2 times
# ('severe', 'case') is used 2 times
# ('indoor', 'space') is used 2 times
# ('There', 'currently') is used 2 times
# ('Main', 'article') is used 2 times
# ('Symptoms', 'COVID19') is used 3 times
# ('COVID19', 'Symptoms') is used 2 times
# ('one', 'person') is used 2 times
# ('person', 'may') is used 2 times
# ('difficulty', 'breathing') is used 3 times
# ('incubation', 'period') is used 2 times
# ('symptomatic', 'people') is used 2 times
# ('people', 'experience') is used 2 times
# ('mouth', 'nose') is used 2 times
# ('infected', 'one') is used 2 times
# ('one', 'infected') is used 2 times

# %%
trigram2 = trigram(covid)
# Out:
# ('severe', 'acute', 'respiratory') is used 2 times
# ('acute', 'respiratory', 'syndrome') is used 2 times
# ('respiratory', 'syndrome', 'coronavirus') is used 2 times
# ('syndrome', 'coronavirus', '2') is used 2 times
# ('coronavirus', '2', 'SARSCoV2') is used 2 times
# ('include', 'fever', 'cough') is used 2 times
# ('fever', 'cough', 'fatigue') is used 2 times
# ('acute', 'respiratory', 'distress') is used 2 times
# ('respiratory', 'distress', 'syndrome') is used 2 times
# ('cough', 'sneeze', 'sings') is used 2 times
# ('early', 'two', 'day') is used 2 times
# ('two', 'week', 'severe') is used 2 times
# ('week', 'severe', 'case') is used 2 times
# ('Symptoms', 'COVID19', 'Symptoms') is used 2 times
# ('COVID19', 'Symptoms', 'COVID19') is used 2 times
# ('symptomatic', 'people', 'experience') is used 2 times
# ('one', 'infected', 'person') is used 2 times

# %%
POStag2 =tagging(covid)
# Out:
# Counter({'NN': 212, 'JJ': 129, 'NNS': 126, 'IN': 125, ',': 88, 'DT': 68, 'CC': 55, '.': 44, 'RB': 36, 'VBN': 33, 'CD': 32, 'VB': 32, 'VBZ': 26, 'VBP': 25, 'MD': 20, 'TO': 18, 'VBG': 13, '(': 12, ')': 12, 'EX': 5, ':': 5, 'VBD': 4, 'WRB': 4, 'RBR': 4, 'JJS': 3, 'WP': 3, 'PRP': 3, 'NNP': 2, 'WDT': 2, 'PRP$': 2, 'JJR': 2, '$': 1, '``': 1, "''": 1})
